# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt


img = cv2.imread(r'C:\Users\julia\Documents\masters\deep_learning\text_recognition\data\train\train\complex\rus_00190_C226OC35.png')
img = img[:, :, 0]
ret, th1 = cv2.threshold(img,100,255,cv2.THRESH_BINARY)

ada_mean_thr = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
ada_gaus_thr = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)', 'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, ada_mean_thr, ada_gaus_thr]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
import os
from utils.datasets import get_dataloaders

os.chdir(r'C:\Users\julia\Documents\masters\deep_learning\text_recognition')


train_dataloader, test_dataloader = get_dataloaders(preprcoessing=False) 
for batch in train_dataloader:
    print('TRAIN')
    print('image', batch['image'].shape)
    print('seq', batch['seq'])
    print('seq_len', batch['seq_len'])
    print('text', batch['text'])
    print()
    break


plt.imshow(batch['image'][0].permute(1, 2, 0).numpy())
plt.show()
# Out:
# TRAIN
# image torch.Size([16, 3, 64, 320])
# seq tensor([21,  9, 10, 10, 15, 15,  2, 10,  1, 11,  2,  9,  3, 11, 19,  8, 10, 10,
#         14,  6, 10,  5, 22, 14, 10,  8, 12, 10,  7,  1, 16, 12,  4,  6, 21,  4,
#         10,  7, 13, 19,  4,  6, 19,  9,  1,  1, 16, 15,  4,  6, 22,  4,  7,  4,
#         22, 22,  4,  6, 21, 10,  1,  2, 12, 15,  2,  3,  5, 16,  2,  6,  5, 17,
#         16,  8,  2, 16,  5,  5,  5, 11, 12,  2, 10,  1, 18, 10, 10, 10, 21, 17,
#          2, 10,  8, 22,  8,  7,  8, 15, 12,  6,  2, 12,  9, 10,  2, 19, 13,  4,
#          6, 12,  7,  3,  8, 13, 20,  4,  6, 17,  6,  8,  9, 18, 16,  2, 10, 10,
#         16,  1,  4,  2, 16, 12,  2, 10,  8], dtype=torch.int32)
# seq_len tensor([9, 9, 8, 8, 8, 8, 8, 9, 8, 9, 9, 8, 8, 8, 9, 9], dtype=torch.int32)
# text ['Y899MM190', 'A182AC799', 'K594XK97', 'B960HB35', 'Y396EC35', 'C800HM35', 'X363XX35', 'Y901BM124', 'H154OH71', 'H444AB190', 'P999YO197', 'X767MB51', 'B891CE35', 'B627ET35', 'O578PH199', 'H031HB197']
